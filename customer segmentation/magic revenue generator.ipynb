# %% [markdown]
# ## Magic revenue generator

# %%
import random
from prettytable import PrettyTable

def print_financials(revenue, year):
    # Mapping years to their respective breakdown functions
    breakdown_functions = {
        2014: breakdown_marketing_2014,
        2015: breakdown_marketing_2015,
        2016: breakdown_marketing_2016,
        2017: breakdown_marketing_2017,
        2018: breakdown_marketing_2018,
        2019: breakdown_marketing_2019,
        2020: breakdown_marketing_2020
    }

    # Get the breakdown function for the specified year
    breakdown_function = breakdown_functions.get(year)

    # Create a PrettyTable instance
    table = PrettyTable()
    table.field_names = ["Category", "Value"]

    if breakdown_function:
        # Get financial data for the specified year
        financials = breakdown_function(revenue)

        # Add rows to the table for each financial category
        for category, value in financials:
            table.add_row([category, f"${value:.2f}"])

        # Print the table
        print(f"Financial Breakdown for sale")
        print(table)

def breakdown_marketing_2014(revenue):
    radio_cost = random.uniform(14.8, 15.5)*revenue/100
    tv_cost = random.uniform(39.8,40.2)*revenue/100
    physical_cost = random.uniform(24.8,25.2)*revenue/100
    instagram_cost = random.uniform(4.8,5.3)*revenue/100
    youtube_cost = random.uniform(14.7,15.1)*revenue/100

    ROI_radio = random.uniform(0.8,0.9)
    ROI_tv = random.uniform(1.2,1.3)
    ROI_physical = random.uniform(1,1.1)
    ROI_instagram = random.uniform(0.5,0.65)
    ROI_youtube = random.uniform(0.9,0.93)

    radio_revenue = ROI_radio*radio_cost + radio_cost
    tv_revenue = ROI_tv*tv_cost + tv_cost
    physical_revenue = ROI_physical*physical_cost + physical_cost
    instagram_revenue = ROI_instagram*instagram_cost + instagram_cost
    youtube_revenue = ROI_youtube*youtube_cost + youtube_cost
    
    return [
        ("Radio Cost", round(radio_cost, 2)),
        ("TV Cost", round(tv_cost, 2)),
        ("Physical Cost", round(physical_cost, 2)),
        ("Instagram Cost", round(instagram_cost, 2)),
        ("YouTube Cost", round(youtube_cost, 2)),
        ("Radio Revenue", round(radio_revenue, 2)),
        ("TV Revenue", round(tv_revenue, 2)),
        ("Physical Revenue", round(physical_revenue, 2)),
        ("Instagram Revenue", round(instagram_revenue, 2)),
        ("YouTube Revenue", round(youtube_revenue, 2))
    ]

def breakdown_marketing_2015(revenue):
    radio_cost = random.uniform(12.8,13.2)*revenue/100
    tv_cost = random.uniform(37.7,38.4)*revenue/100
    physical_cost = random.uniform(22.7,23.2)*revenue/100
    instagram_cost = random.uniform(7.8,8.5)*revenue/100
    youtube_cost = random.uniform(17.6,18)*revenue/100

    ROI_radio = random.uniform(0.65,0.7)
    ROI_tv = random.uniform(1,1.1)
    ROI_physical = random.uniform(0.95,1)
    ROI_instagram = random.uniform(0.8,0.9)
    ROI_youtube = random.uniform(1,1.1)

    radio_revenue = ROI_radio*radio_cost + radio_cost
    tv_revenue = ROI_tv*tv_cost + tv_cost
    physical_revenue = ROI_physical*physical_cost + physical_cost
    instagram_revenue = ROI_instagram*instagram_cost + instagram_cost
    youtube_revenue = ROI_youtube*youtube_cost + youtube_cost
    
    return [
        ("Radio Cost", round(radio_cost, 2)),
        ("TV Cost", round(tv_cost, 2)),
        ("Physical Cost", round(physical_cost, 2)),
        ("Instagram Cost", round(instagram_cost, 2)),
        ("YouTube Cost", round(youtube_cost, 2)),
        ("Radio Revenue", round(radio_revenue, 2)),
        ("TV Revenue", round(tv_revenue, 2)),
        ("Physical Revenue", round(physical_revenue, 2)),
        ("Instagram Revenue", round(instagram_revenue, 2)),
        ("YouTube Revenue", round(youtube_revenue, 2))
    ]

def breakdown_marketing_2016(revenue):
    radio_cost = random.uniform(9.8,10.2)*revenue/100
    tv_cost = random.uniform(34.7,35.3)*revenue/100
    physical_cost = random.uniform(19.7,20.4)*revenue/100
    instagram_cost = random.uniform(12.1,12.5)*revenue/100
    youtube_cost = random.uniform(21.7,22.2)*revenue/100

    ROI_radio = random.uniform(0.58,0.62)
    ROI_tv = random.uniform(0.9,0.95)
    ROI_physical = random.uniform(0.82,0.85)
    ROI_instagram = random.uniform(0.95,1.05)
    ROI_youtube = random.uniform(1.18,1.25)

    radio_revenue = ROI_radio*radio_cost + radio_cost
    tv_revenue = ROI_tv*tv_cost + tv_cost
    physical_revenue = ROI_physical*physical_cost + physical_cost
    instagram_revenue = ROI_instagram*instagram_cost + instagram_cost
    youtube_revenue = ROI_youtube*youtube_cost + youtube_cost
    
    return [
        ("Radio Cost", round(radio_cost, 2)),
        ("TV Cost", round(tv_cost, 2)),
        ("Physical Cost", round(physical_cost, 2)),
        ("Instagram Cost", round(instagram_cost, 2)),
        ("YouTube Cost", round(youtube_cost, 2)),
        ("Radio Revenue", round(radio_revenue, 2)),
        ("TV Revenue", round(tv_revenue, 2)),
        ("Physical Revenue", round(physical_revenue, 2)),
        ("Instagram Revenue", round(instagram_revenue, 2)),
        ("YouTube Revenue", round(youtube_revenue, 2))
    ]

def breakdown_marketing_2017(revenue):
    radio_cost = random.uniform(7.8,8.4)*revenue/100
    tv_cost = random.uniform(31.5,32.4)*revenue/100
    physical_cost = random.uniform(17.7,18.4)*revenue/100
    instagram_cost = random.uniform(14.7,15.4)*revenue/100
    tiktok_cost = random.uniform(2.0,2.5)*revenue/100
    youtube_cost = random.uniform(21.7,22.2)*revenue/100

    ROI_radio = random.uniform(0.53,0.57)
    ROI_tv = random.uniform(0.85,0.9)
    ROI_physical = random.uniform(0.77,0.8)
    ROI_instagram = random.uniform(1.1,1.18)
    ROI_tiktok = random.uniform(0.6,0.75)
    ROI_youtube = random.uniform(1.25,1.3)

    radio_revenue = ROI_radio*radio_cost + radio_cost
    tv_revenue = ROI_tv*tv_cost + tv_cost
    physical_revenue = ROI_physical*physical_cost + physical_cost
    instagram_revenue = ROI_instagram*instagram_cost + instagram_cost
    tiktok_revenue = ROI_tiktok*tiktok_cost + tiktok_cost
    youtube_revenue = ROI_youtube*youtube_cost + youtube_cost
    
    return [
        ("Radio Cost", round(radio_cost, 2)),
        ("TV Cost", round(tv_cost, 2)),
        ("Physical Cost", round(physical_cost, 2)),
        ("Instagram Cost", round(instagram_cost, 2)),
        ("YouTube Cost", round(youtube_cost, 2)),
        ("Radio Revenue", round(radio_revenue, 2)),
        ("TV Revenue", round(tv_revenue, 2)),
        ("Physical Revenue", round(physical_revenue, 2)),
        ("Instagram Revenue", round(instagram_revenue, 2)),
        ("TikTok Revenue", round(tiktok_revenue, 2)),
        ("YouTube Revenue", round(youtube_revenue, 2))
    ]

def breakdown_marketing_2018(revenue):
    radio_cost = random.uniform(5.8,6.1)*revenue/100
    tv_cost = random.uniform(27.7,28.2)*revenue/100
    physical_cost = random.uniform(14.8,15.1)*revenue/100
    instagram_cost = random.uniform(17.6,18.3)*revenue/100
    tiktok_cost = random.uniform(4.7,5.3)*revenue/100
    youtube_cost = random.uniform(27.5,28.4)*revenue/100

    ROI_radio = random.uniform(0.48,0.52)
    ROI_tv = random.uniform(0.78,0.82)
    ROI_physical = random.uniform(0.7,0.74)
    ROI_instagram = random.uniform(1.15,1.25)
    ROI_tiktok = random.uniform(0.8,0.9)
    ROI_youtube = random.uniform(1.3,1.38)

    radio_revenue = ROI_radio*radio_cost + radio_cost
    tv_revenue = ROI_tv*tv_cost + tv_cost
    physical_revenue = ROI_physical*physical_cost + physical_cost
    instagram_revenue = ROI_instagram*instagram_cost + instagram_cost
    tiktok_revenue = ROI_tiktok*tiktok_cost + tiktok_cost
    youtube_revenue = ROI_youtube*youtube_cost + youtube_cost
    
    return [
        ("Radio Cost", round(radio_cost, 2)),
        ("TV Cost", round(tv_cost, 2)),
        ("Physical Cost", round(physical_cost, 2)),
        ("Instagram Cost", round(instagram_cost, 2)),
        ("YouTube Cost", round(youtube_cost, 2)),
        ("Radio Revenue", round(radio_revenue, 2)),
        ("TV Revenue", round(tv_revenue, 2)),
        ("Physical Revenue", round(physical_revenue, 2)),
        ("Instagram Revenue", round(instagram_revenue, 2)),
        ("TikTok Revenue", round(tiktok_revenue, 2)),
        ("YouTube Revenue", round(youtube_revenue, 2))
    ]

def breakdown_marketing_2019(revenue):
    radio_cost = random.uniform(4.7,5.2)*revenue/100
    tv_cost = random.uniform(24.7,25.3)*revenue/100
    physical_cost = random.uniform(11.9,12.5)*revenue/100
    instagram_cost = random.uniform(19.8,20.1)*revenue/100
    tiktok_cost = random.uniform(9.7,10.5)*revenue/100
    youtube_cost = random.uniform(14.5,15.2)*revenue/100

    ROI_radio = random.uniform(0.42,0.46)
    ROI_tv = random.uniform(0.72,0.78)
    ROI_physical = random.uniform(0.64,0.68)
    ROI_instagram = random.uniform(1.3,1.35)
    ROI_tiktok = random.uniform(0.9,1)
    ROI_youtube = random.uniform(1.37,1.4)

    radio_revenue = ROI_radio*radio_cost + radio_cost
    tv_revenue = ROI_tv*tv_cost + tv_cost
    physical_revenue = ROI_physical*physical_cost + physical_cost
    instagram_revenue = ROI_instagram*instagram_cost + instagram_cost
    tiktok_revenue = ROI_tiktok*tiktok_cost + tiktok_cost
    youtube_revenue = ROI_youtube*youtube_cost + youtube_cost
    
    return [
        ("Radio Cost", round(radio_cost, 2)),
        ("TV Cost", round(tv_cost, 2)),
        ("Physical Cost", round(physical_cost, 2)),
        ("Instagram Cost", round(instagram_cost, 2)),
        ("YouTube Cost", round(youtube_cost, 2)),
        ("Radio Revenue", round(radio_revenue, 2)),
        ("TV Revenue", round(tv_revenue, 2)),
        ("Physical Revenue", round(physical_revenue, 2)),
        ("Instagram Revenue", round(instagram_revenue, 2)),
        ("TikTok Revenue", round(tiktok_revenue, 2)),
        ("YouTube Revenue", round(youtube_revenue, 2))
    ]

def breakdown_marketing_2020(revenue):
    radio_cost = random.uniform(4.3,4.7)*revenue/100
    tv_cost = random.uniform(21.7,22.4)*revenue/100
    physical_cost = random.uniform(9.6,10.1)*revenue/100
    instagram_cost = random.uniform(21.8,22.7)*revenue/100
    tiktok_cost = random.uniform(14.5,15.2)*revenue/100
    youtube_cost = random.uniform(26.4,27)*revenue/100

    ROI_radio = random.uniform(0.37,0.4)
    ROI_tv = random.uniform(0.65,0.7)
    ROI_physical = random.uniform(0.54,0.58)
    ROI_instagram = random.uniform(1.35,1.4)
    ROI_tiktok = random.uniform(1.2,1.3)
    ROI_youtube = random.uniform(1.42,1.46)

    radio_revenue = ROI_radio*radio_cost + radio_cost
    tv_revenue = ROI_tv*tv_cost + tv_cost
    physical_revenue = ROI_physical*physical_cost + physical_cost
    instagram_revenue = ROI_instagram*instagram_cost + instagram_cost
    tiktok_revenue = ROI_tiktok*tiktok_cost + tiktok_cost
    youtube_revenue = ROI_youtube*youtube_cost + youtube_cost
    
    return [
        ("Radio Cost", round(radio_cost, 2)),
        ("TV Cost", round(tv_cost, 2)),
        ("Physical Cost", round(physical_cost, 2)),
        ("Instagram Cost", round(instagram_cost, 2)),
        ("YouTube Cost", round(youtube_cost, 2)),
        ("Radio Revenue", round(radio_revenue, 2)),
        ("TV Revenue", round(tv_revenue, 2)),
        ("Physical Revenue", round(physical_revenue, 2)),
        ("Instagram Revenue", round(instagram_revenue, 2)),
        ("TikTok Revenue", round(tiktok_revenue, 2)),
        ("YouTube Revenue", round(youtube_revenue, 2))
    ]

# %% [markdown]
# | Year | Sale Event             | Revenue   | Advertising Spend | Sales Period                   |
# |------|------------------------|-----------|-------------------|--------------------------------|
# | 2014 | Easter Sale            | 317784    | 31778.4           | April 15 - April 20            |
# | 2014 | Mid-Year Sale          | 688305    | 68830.5           | June 15 - June 30              |
# | 2014 | Halloween              | 560629    | 56062.9           | October 21 - October 31        |
# | 2014 | Christmas              | 2165445   | 216544.5          | December                       |
# | 2015 | St. Patrick's Day      | 573505    | 57350.5           | March 6 - March 17             |
# | 2015 | Easter Sale            | 294423    | 29442.3           | April 15 - April 20            |
# | 2015 | Mid-Year Sale          | 665198    | 66519.8           | June 15 - June 30              |
# | 2015 | Christmas              | 1914092   | 191409.2          | December                       |
# | 2016 | Easter Sale            | 337029    | 33702.9           | April 15 - April 20            |
# | 2016 | Cinco de Mayo          | 638659    | 63865.9           | May 1 - May 14                 |
# | 2016 | Mid-Year Sale          | 809596    | 80959.6           | June 15 - June 30              |
# | 2016 | Christmas              | 1870951   | 187095.1          | December                       |
# | 2017 | Easter Sale            | 290357    | 29035.7           | April 15 - April 20            |
# | 2017 | Mid-Year Sale          | 879080    | 87908             | June 15 - June 30              |
# | 2017 | Drinks Bonanza         | 585299    | 58529.9           | September 7 - September 18     |
# | 2017 | Christmas              | 1823148   | 182314.8          | December                       |
# | 2018 | Easter Sale            | 240650    | 24065             | April 15 - April 20            |
# | 2018 | Mid-Year Sale          | 825577    | 82557.7           | June 15 - June 30              |
# | 2018 | Food and Beverage Day  | 833260    | 83326             | November 1 - November 18       |
# | 2018 | Christmas              | 1776644   | 177664.4          | December                       |
# | 2019 | Super Mart Sale        | 641441    | 64144.1           | February 3 - February 15       |
# | 2019 | Easter Sale            | 298201    | 29820.1           | April 15 - April 20            |
# | 2019 | Mid-Year Sale          | 831319    | 83131.9           | June 15 - June 30              |
# | 2019 | Christmas              | 1814662   | 181466.2          | December                       |
# | 2020 | Easter Sale            | 273684    | 27368.4           | April 15 - April 20            |
# | 2020 | Markdown Mega Sale     | 422629    | 42262.9           | May 15 - May 23                |
# | 2020 | Mid-Year Sale          | 818726    | 81872.6           | June 15 - June 30              |
# | 2020 | Christmas              | 2020622   | 202062.2          | December                       |

# %%
## Insert code here
#print_financials(marketing_spend,year)
# e.g(2019 CHRISTMAS) print_financials(181466.2,2019)

print_financials(29820.1,2019)
# Out:
# Financial Breakdown for sale
# +-------------------+-----------+
# |      Category     |   Value   |
# +-------------------+-----------+
# |     Radio Cost    |  $1454.60 |
# |      TV Cost      |  $7525.66 |
# |   Physical Cost   |  $3647.87 |
# |   Instagram Cost  |  $5986.42 |
# |    YouTube Cost   |  $4336.31 |
# |   Radio Revenue   |  $2095.57 |
# |     TV Revenue    | $13022.73 |
# |  Physical Revenue |  $5984.74 |
# | Instagram Revenue | $14046.32 |
# |   TikTok Revenue  |  $5991.89 |
# |  YouTube Revenue  | $10399.93 |
# +-------------------+-----------+
